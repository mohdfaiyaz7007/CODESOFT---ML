# %%
import pandas as pd
import numpy as np
descriptions = []
genres = []

with open(r'/content/train_data.txt', 'r',encoding='utf-8') as file:
    for line in file:
        parts = line.strip().split(":::")
        if len(parts) == 3:
            descriptions.append(parts[1].strip())
            genres.append(parts[2].strip())

data = pd.DataFrame({'description': descriptions, 'genre': genres})

# %%
import pandas as pd
descriptions = []
genres = []
# Reading the text file anad stores the description and genres.

with open(r'/content/train_data.txt', 'r', encoding='utf-8') as file:
    for line in file:
        parts = line.strip().split(":::")
        if len(parts) == 4:
            descriptions.append(parts[3].strip())
            genres.append(parts[2].strip())

# Create a DataFrame from the extracted data
data = pd.DataFrame({'description': descriptions, 'genre': genres})

# Import the data to a CSV file
data.to_csv('/content/train_data.csv', index=False)

# %%
# Now test_data will be imported here.
import pandas as pd
descriptions = []
genres = []

with open(r'/content/test_data_solution.txt', 'r', encoding='utf-8') as file:
    for line in file:
        parts = line.strip().split(":::")
        if len(parts) == 4:
            descriptions.append(parts[3].strip())
            genres.append(parts[2].strip())
data = pd.DataFrame({'description': descriptions, 'genre': genres})
data.to_csv('/content/test_data.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-c7e11c3a128b> in <cell line: 5>()
#       3 genres = []
#       4
# ----> 5 with open(r'/content/test_data_solution.txt', 'r', encoding='utf-8') as file:
#       6     for line in file:
#       7         parts = line.strip().split(":::")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/test_data_solution.txt'

# %%
df_train=pd.read_csv('/content/train_data.csv')
x_train=df_train['description']
x_train
# Out:
# 0       Jimmy is an environmentalist who finds comfort...
# 1       On Top - Iceland, a lighthouse, a cold winter ...
# 2       Between 1960 and 1962, more than 14,000 Cuban ...
# 3       Meat the Truth is a high-profile documentary w...
# 4       Who's Hungry is part of an ongoing series of e...
#                               ...
# 1619    Set in a women's restroom, Intermission is a c...
# 1620    Maria is starting a relationship with Hector, ...
# 1621    Sikil tells the story of two men and a woman w...
# 1622    Survivors describe their experiences in severe...
# 1623    A small island in the Libyan Sea. A frontier. ...
# Name: description, Length: 1624, dtype: object

# %%
y=df_train['genre']
y[0:50]
# Out:
# 0         fantasy
# 1           short
# 2     documentary
# 3     documentary
# 4           drama
# 5           short
# 6          family
# 7           drama
# 8           drama
# 9     documentary
# 10      adventure
# 11         comedy
# 12         comedy
# 13         comedy
# 14         comedy
# 15    documentary
# 16       thriller
# 17         comedy
# 18    documentary
# 19      talk-show
# 20         horror
# 21    documentary
# 22    documentary
# 23        fantasy
# 24    documentary
# 25          drama
# 26         comedy
# 27      game-show
# 28        history
# 29      adventure
# 30         action
# 31         comedy
# 32    documentary
# 33          drama
# 34          music
# 35        romance
# 36          short
# 37         comedy
# 38          drama
# 39          drama
# 40         comedy
# 41         comedy
# 42          drama
# 43          short
# 44         comedy
# 45      game-show
# 46    documentary
# 47         family
# 48          drama
# 49         comedy
# Name: genre, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
unique=np.unique(df_train['genre'])
unique.sort()
label_encoder = LabelEncoder()
encoded_genres = label_encoder.fit_transform(unique)
encoded_dict={}
for i,j in zip(unique,encoded_genres):
    encoded_dict[i]=j
print(encoded_dict)
# Out:
# {'action': 0, 'adult': 1, 'adventure': 2, 'animation': 3, 'biography': 4, 'comedy': 5, 'crime': 6, 'documentary': 7, 'drama': 8, 'family': 9, 'fantasy': 10, 'game-show': 11, 'history': 12, 'horror': 13, 'music': 14, 'musical': 15, 'mystery': 16, 'news': 17, 'reality-tv': 18, 'romance': 19, 'sci-fi': 20, 'short': 21, 'sport': 22, 'talk-show': 23, 'thriller': 24, 'war': 25, 'western': 26}

# %%
df_train['encoded']=0
for i in range(len(df_train)):
    df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# Out:
# Streaming output truncated to the last 5000 lines.
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# ...
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]
# <ipython-input-37-8db9ceb52cc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['encoded'][i]=encoded_dict[df_train['genre'][i]]

# %%
y_train=df_train['encoded']
y_train
# Out:
# 0       10
# 1       21
# 2        7
# 3        7
# 4        8
#         ..
# 1619    21
# 1620     5
# 1621     8
# 1622     7
# 1623     7
# Name: encoded, Length: 1624, dtype: int64

# %%
x_train
# Out:
# 0       Jimmy is an environmentalist who finds comfort...
# 1       On Top - Iceland, a lighthouse, a cold winter ...
# 2       Between 1960 and 1962, more than 14,000 Cuban ...
# 3       Meat the Truth is a high-profile documentary w...
# 4       Who's Hungry is part of an ongoing series of e...
#                               ...
# 1619    Set in a women's restroom, Intermission is a c...
# 1620    Maria is starting a relationship with Hector, ...
# 1621    Sikil tells the story of two men and a woman w...
# 1622    Survivors describe their experiences in severe...
# 1623    A small island in the Libyan Sea. A frontier. ...
# Name: description, Length: 1624, dtype: object

# %%
df_test=pd.read_csv('/content/test_data.csv')
x_test=df_test['description']
x_test
# Out:
# 0        L.R. Brane loves his life - his car, his apart...
# 1        Spain, March 1964: Quico is a very naughty chi...
# 2        One year in the life of Albin and his family o...
# 3        His father has died, he hasn't spoken with his...
# 4        Before he was known internationally as a marti...
#                                ...
# 64225    REVIVAL is hybrid of every film idiom: Broadwa...
# 64226    With the tragic events and circus surrounding ...
# 64227    In his younger days , a dashing officer,Colone...
# 64228    The film documentary TEPUY is a thrilling stor...
# 64229    Millionaire Baretti pays a gang to rob an atom...
# Name: description, Length: 64230, dtype: object

# %%
y_test=df_test['genre']
y_test
# Out:
# 0           thriller
# 1             comedy
# 2        documentary
# 3              drama
# 4              drama
#             ...
# 64225        musical
# 64226    documentary
# 64227          drama
# 64228    documentary
# 64229      adventure
# Name: genre, Length: 64230, dtype: object

# %%
x_train
# Out:
# 0       Jimmy is an environmentalist who finds comfort...
# 1       On Top - Iceland, a lighthouse, a cold winter ...
# 2       Between 1960 and 1962, more than 14,000 Cuban ...
# 3       Meat the Truth is a high-profile documentary w...
# 4       Who's Hungry is part of an ongoing series of e...
#                               ...
# 1619    Set in a women's restroom, Intermission is a c...
# 1620    Maria is starting a relationship with Hector, ...
# 1621    Sikil tells the story of two men and a woman w...
# 1622    Survivors describe their experiences in severe...
# 1623    A small island in the Libyan Sea. A frontier. ...
# Name: description, Length: 1624, dtype: object

# %%
df_test['encoded']=0
for i in range(len(df_test)):
    df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# Out:
# Streaming output truncated to the last 5000 lines.
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]
# <ipython-input-43-b60bf8c0b59c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['encoded'][i]=encoded_dict[df_test['genre'][i]]

# %%
y_test=df_test['encoded']

# %%
x_train
# Out:
# 0       Jimmy is an environmentalist who finds comfort...
# 1       On Top - Iceland, a lighthouse, a cold winter ...
# 2       Between 1960 and 1962, more than 14,000 Cuban ...
# 3       Meat the Truth is a high-profile documentary w...
# 4       Who's Hungry is part of an ongoing series of e...
#                               ...
# 1619    Set in a women's restroom, Intermission is a c...
# 1620    Maria is starting a relationship with Hector, ...
# 1621    Sikil tells the story of two men and a woman w...
# 1622    Survivors describe their experiences in severe...
# 1623    A small island in the Libyan Sea. A frontier. ...
# Name: description, Length: 1624, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score,classification_report

# %%
vector=CountVectorizer()
x_train=vector.fit_transform(x_train)
x_test=vector.transform(x_test)

# %%
naive=MultinomialNB()
naive.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
y_test
# Out:
# 0        24
# 1         5
# 2         7
# 3         8
# 4         8
#          ..
# 64225    15
# 64226     7
# 64227     8
# 64228     7
# 64229     2
# Name: encoded, Length: 64230, dtype: int64

# %%
y_pred=naive.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.4367585240541803
